# %%
# %%bash
# cd cli_assignment
# ls

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
# %%bash
# cd cli_assignment
# touch README.md
# ls

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
# %%bash
# cd cli_assignment
# echo "# CLI Assignment" > "README.md"
# cat README.md

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
# %%bash
# cd cli_assignment
# mkdir data
# ls -l

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
# %%bash
# man ls
# ls -a

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
