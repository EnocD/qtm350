# %% [markdown]
# #1

# %% [markdown]
# Code: <br>
# mkdir data_project <br>
# cd data_project <br>
# git init <br>
# git status

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #2

# %% [markdown]
# Code: <br>
# touch data_cleaning.py <br>
# touch data_analysis.py <br>
# touch visualisation.py <br>
# git add . <br>
# git status

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #3 and #4

# %% [markdown]
# Code: <br>
# git commit -m "Initial commit with data processing scripts" <br>
# git log

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #5

# %% [markdown]
# Accidentally did git add . twice, so it appears twice in commit

# %% [markdown]
# Code: <br>
# git add . <br>
# git commit -m "Add cleaning_data function to data_cleaning.py"

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #6

# %% [markdown]
# Code: <br>
# git branch feature-exploration <br>
# git checkout feature-exploration

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #7

# %% [markdown]
# Code : <br>
# touch exploratory_analysis.py <br>
# git add exploratory_analysis.py <br>
# git commit -m "Add clean_data function to data_cleaning.py"

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #8 and #9

# %% [markdown]
# Code: <br>
# git checkout master <br>
# git merge feature_exploration

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# #10

# %% [markdown]
# I believe the merge command already committed it so it looks like this

# %% [markdown]
# Code:  <br>
# git branch

# %% [markdown]
# ![image.png](attachment:image.png)
